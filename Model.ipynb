# %% [markdown]
# ## Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Import Libraries

# %%
import h5py                     # Hierarchical data format
import cv2                      # Reading and writing images
import numpy as np              # Numpy library
import matplotlib.pyplot as plt # Visualization library
import tensorflow as tf         # Tensorflor library
import os                       # Operating system

import seaborn as sns;          # Visualization library
sns.set()
sns.set(style="white")
sns.set(style="whitegrid", color_codes = True)

# %% [markdown]
# ## Data

# %% [markdown]
# ### Loading

# %%
# This should match your Google Drive
path_project = ('/content/drive/MyDrive/LungCancer')

# Load the gesture data
train_images = []
train_labels = []
test_images = []
test_labels = []

path_data = os.path.join( path_project, 'Data', 'data.h5')
with h5py.File(path_data, "r") as f:
  train_images = f['train-images'][:]
  train_labels = f['train-labels'][:]
  test_images = f['test-images'][:]
  test_labels = f['test-labels'][:]

# %%
# confirm the sizes of the data
print('Train set images: ', train_images.shape, 'labels: ', train_labels.shape )
print('Test set images: ', test_images.shape, 'labels: ', test_labels.shape )
# Out:
# Train set images:  (767, 256, 256, 3) labels:  (767,)
# Test set images:  (330, 256, 256, 3) labels:  (330,)

# %%
# classes
class_names = ['Normal', 'Bengin', 'Malignant']

# %% [markdown]
# ### Visualize Training Samples

# %%
# The number of images to visualize
num_images_to_display = 24

# Select random indices from the image array
indices = np.random.choice(train_images.shape[0], num_images_to_display)

# Visualize the images
plt.figure(figsize=(10,10))
for i in range(num_images_to_display):
    index = indices[i]
    label = train_labels[index]
    plt.subplot(6,6,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[index])
    plt.xlabel( class_names[label] )
plt.show()

# %% [markdown]
# ## Model

# %% [markdown]
# ## Results
